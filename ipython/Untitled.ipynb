# %%
import json

path = '/home/mania/serverless-social-network-multithreaded/load-test/trace.json'

with open(path, 'r') as fd:
    print(json.dumps(json.load(fd), indent = 4))
# Out:
# [
#     {
#         "read_user_timeline_pipeline": {
#             "request_id": 669201556497616545,
#             "user_id": 57741,
#             "start": 0,
#             "stop": 10
#         },
#         "objects": [
#             {
#                 "oid": 8930063348801649516,
#                 "type": "text",
#                 "size": 154,
#                 "author": 57741
#             },
#             {
#                 "oid": 1235204427481551352,
#                 "type": "PIC",
#                 "size": 180214,
#                 "author": 57741
#             },
#             {
#                 "oid": 5546087978084345520,
#                 "type": "PIC",
#                 "size": 175378,
#                 "author": 57741
#             },
#             {
#                 "oid": 5934254512214334352,
#                 "type": "PIC",
#                 "size": 1087,
#                 "author": 57741
#             },
#             {
#                 "oid": 7090488132778387852,
# ...
